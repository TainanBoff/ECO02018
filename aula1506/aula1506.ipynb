# %% [markdown]
# # Aula de 15/06
#
# Pandas: manipulacao de dados.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

s = pd.Series([1,3,5,np.nan,6,8])
print("Os valores assumidos por s sao os seguintes:\n",s)
# Out:
# Os valores assumidos por s sao os seguintes:
#  0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
t = pd.Series(np.random.randn(5), index=["Segunda", "Terca","Quarta","Quinta","Sexta"])
print("Os valores assumidos por t sao os seguintes:\n",t)
# Out:
# Os valores assumidos por t sao os seguintes:
#  Segunda    3.337476
# Terca     -0.452113
# Quarta     0.209367
# Quinta     0.847399
# Sexta     -2.346110
# dtype: float64

# %%
dates = pd.date_range("20180612", periods = 6)
dados1 = pd.Series(np.random.randn(6), index = dates)
print(dados1)
# Out:
# 2018-06-12    0.739512
# 2018-06-13    0.494135
# 2018-06-14    0.691143
# 2018-06-15    0.361168
# 2018-06-16   -3.672074
# 2018-06-17   -0.091108
# Freq: D, dtype: float64

# %% [markdown]
# ## **Leitura ou coleta de dados**

# %%
dados3 = pd.read_csv("/home/tainan/Downloads/STI-20180615200423099.csv", header='infer', sep = ";", decimal = ",", thousands = ".", infer_datetime_format = True)
dados3
# Out:
#     Date                   PIB
# 0   1962                  0.00
# 1   1963                  0.00
# 2   1964                  0.01
# 3   1965                  0.02
# 4   1966                  0.02
# 5   1967                  0.03
# 6   1968                  0.04
# 7   1969                  0.06
# 8   1970                  0.07
# 9   1971                  0.09
# 10  1972                  0.13
# 11  1973                  0.19
# 12  1974                  0.27
# 13  1975                  0.38
# 14  1976                  0.59
# 15  1977                  0.91
# 16  1978                  1.32
# 17  1979                  2.17
# 18  1980                  4.55
# 19  1981                  8.73
# 20  1982                 17.70
# 21  1983                 39.78
# 22  1984                126.50
# 23  1985                475.53
# 24  1986              1,273.68
# 25  1987              4,037.81
# 26  1988             29,375.63
# 27  1989            425,595.31
# 28  1990         11,548,794.55
# ...

# %%
grafpib = plt.plot(dados3.Date, dados3.PIB)
plt.show(grafpib)

# %%
divmob = pd.read_csv("http://api.bcb.gov.br/dados/serie/bcdata.sgs.4151/dados?formato=csv", sep = ";", decimal = ",", thousands = ".", parse_dates = True, infer_datetime_format = True, dayfirst = True)
divmob
# Out:
#            data         valor
# 0    01/01/1991  2.261821e+07
# 1    01/02/1991  2.414748e+07
# 2    01/03/1991  2.683879e+07
# 3    01/04/1991  2.879735e+07
# 4    01/05/1991  3.156397e+07
# 5    01/06/1991  3.451732e+07
# 6    01/07/1991  3.631689e+07
# 7    01/08/1991  4.089243e+07
# 8    01/09/1991  4.652341e+07
# 9    01/10/1991  5.486986e+07
# 10   01/11/1991  7.153583e+07
# 11   01/12/1991  9.305481e+07
# 12   01/01/1992  1.193752e+08
# 13   01/02/1992  1.549849e+08
# 14   01/03/1992  1.957233e+08
# 15   01/04/1992  2.570387e+08
# 16   01/05/1992  3.188072e+08
# 17   01/06/1992  3.872216e+08
# 18   01/07/1992  4.952852e+08
# 19   01/08/1992  6.220940e+08
# 20   01/09/1992  7.751454e+08
# 21   01/10/1992  1.005998e+09
# 22   01/11/1992  1.213223e+09
# 23   01/12/1992  1.477431e+09
# 24   01/01/1993  1.829572e+09
# 25   01/02/1993  2.390734e+09
# 26   01/03/1993  3.018938e+09
# 27   01/04/1993  3.889241e+09
# 28   01/05/1993  4.993264e+09
# 29   01/06/1993  6.516860e+09
# ...

# %%
grafs = plt.plot(s)
plt.show(grafs)
